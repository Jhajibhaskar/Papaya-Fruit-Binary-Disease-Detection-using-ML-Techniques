# %%
import cv2 as cv
import os

path = 'C:\\Users\\ujjwa\\Downloads\\Final Year Project\\Augmentation\\Diseased_Resized' #Input Folder Path
d_path = 'C:\\Users\\ujjwa\\Downloads\\Final Year Project\\Augmentation\\Diseased Augmented' #Output Folder Path

# Check if the destination directory exists, and create it if necessary
if not os.path.exists(d_path):
    os.makedirs(d_path)

list_of_files = os.listdir(path)

for file_name in list_of_files:
    # Construct the full file path
    full_path = os.path.join(path, file_name)

    if os.path.isfile(full_path):
        image = cv.imread(full_path)

        if image is not None:
            output_filename = 'a0_' + file_name
            output_path = os.path.join(d_path, output_filename)
            cv.imwrite(output_path, image)
            print(f"Saved {output_filename}")

            # Augmenting
            image2 = cv.flip(image, 1)
            image3 = cv.flip(image, -1)
            image4 = cv.flip(image2, -1)
            cv.imwrite(os.path.join(d_path, 'a1_' + file_name), image2)
            cv.imwrite(os.path.join(d_path, 'a2_' + file_name), image3)
            cv.imwrite(os.path.join(d_path, 'a3_' + file_name), image4)

for file_name in list_of_files:
    # Construct the full file path
    full_path = os.path.join(path, file_name)

    if os.path.isfile(full_path):
        image = cv.imread(full_path)

        if image is not None:
            # Augmenting
            image2 = cv.rotate(image, cv.ROTATE_90_CLOCKWISE)
            image3 = cv.rotate(image, cv.ROTATE_180)
            image4 = cv.rotate(image, cv.ROTATE_90_COUNTERCLOCKWISE)
            cv.imwrite(os.path.join(d_path, 'r1_' + file_name), image2)
            cv.imwrite(os.path.join(d_path, 'r2_' + file_name), image3)
            cv.imwrite(os.path.join(d_path, 'r3_' + file_name), image4)

print("Augmentation successfull")
# Out:
# Saved a0_TR000007-2.jpg
# Saved a0_TR000008-2.jpg
# Saved a0_TR000009-2-8.jpg
# Saved a0_TR000010-2-6.jpg
# Saved a0_TR000011-2-8.jpg
# Saved a0_TR000021-2-3.jpg
# Saved a0_TR000022-2.jpg
# Saved a0_TR000036-2.jpg
# Saved a0_TR000331-2.jpg
# Saved a0_TR000332-2.jpg
# Saved a0_TR000333-2.jpg
# Saved a0_TR000335-2.jpg
# Saved a0_TR000336-2.jpg
# Saved a0_TR000337-2.jpg
# Saved a0_TR000338-2.jpg
# Saved a0_TR000339-2.jpg
# Saved a0_TR000340-2.jpg
# Saved a0_TR000341-2.jpg
# Saved a0_TR000342-2-1-3.jpg
# Saved a0_TR000343-2.jpg
# Saved a0_TR000344-2.jpg
# Saved a0_TR000345-2.jpg
# Saved a0_TR000347-2.jpg
# Saved a0_TR000348-2-7.jpg
# Saved a0_TR000349-2-3.jpg
# Saved a0_TR000353-2.jpg
# Saved a0_TR000355-2-8.jpg
# Saved a0_TR000771-2.jpg
# Saved a0_TR000875-2-7.jpg
# Saved a0_TR003476-2.jpg
# Saved a0_TR003477-2.jpg
# Saved a0_TR003478-2.jpg
# Saved a0_TR003479-2.jpg
# Saved a0_TR003480-2.jpg
# Saved a0_TR003481-2.jpg
# Saved a0_TR003482-2.jpg
# Saved a0_TR003483-2.jpg
# Saved a0_TR003484-2.jpg
# Saved a0_TR003485-2.jpg
# Saved a0_TR003486-2.jpg
# Saved a0_TR003487-2.jpg
# Saved a0_TR003488-2.jpg
# Saved a0_TR003489-2.jpg
# Saved a0_TR003490-2.jpg
# Saved a0_TR003491-2.jpg
# Saved a0_TR003492-2.jpg
# Saved a0_TR003493-2.jpg
# Saved a0_TR003495-2-8.jpg
# Saved a0_TR003496-2.jpg
# Saved a0_TR003497-2.jpg
# Saved a0_TR003498-2.jpg
# Saved a0_TR003499-2.jpg
# Saved a0_TR003500-2.jpg
# Saved a0_TR003501-2.jpg
# Saved a0_TR003502-2.jpg
# Saved a0_TR003503-2.jpg
# Saved a0_TR003504-2.jpg
# Saved a0_TR003505-2.jpg
# Saved a0_TR003506-2.jpg
# Saved a0_TR003507-2.jpg
# Saved a0_TR003508-2.jpg
# Saved a0_TR003509-2.jpg
# Saved a0_TR003510-2.jpg
# Saved a0_TR003511-2.jpg
# Saved a0_TR003512-2.jpg
# Saved a0_TR003513-2-1.jpg
# Saved a0_TR003514-2.jpg
# Saved a0_TR003515-2.jpg
# Saved a0_TR003516-2.jpg
# Saved a0_TR003517-2.jpg
# Saved a0_TR004036-2.jpg
# Saved a0_TR005824-2.jpg
# Saved a0_TR005825-2-8.jpg
# Saved a0_TR005826-2.jpg
# Saved a0_TR005828-2.jpg
# Saved a0_TR005829-2.jpg
# Saved a0_TR005830-2.jpg
# Saved a0_TR005831-2.jpg
# Saved a0_TR005832-2.jpg
# Saved a0_TR005833-2.jpg
# Saved a0_TR005834-2-8.jpg
# Saved a0_TR005835-2.jpg
# Saved a0_TR005836-2.jpg
# Saved a0_TR005837-2.jpg
# Saved a0_TR005838-2.jpg
# Saved a0_TR005839-2.jpg
# Saved a0_TR005840-2.jpg
# Saved a0_TR005841-2.jpg
# Saved a0_TR005842-2.jpg
# Saved a0_TR005843-2.jpg
# Saved a0_TR005844-2.jpg
# Saved a0_TR005845-2.jpg
# Saved a0_TR005846-2.jpg
# Saved a0_TR005847-2.jpg
# Saved a0_TR005848-2.jpg
# Saved a0_TR005849-2.jpg
# Saved a0_TR005850-2.jpg
# Saved a0_TR005851-2.jpg
# Saved a0_TR005852-2.jpg
# Saved a0_TR005853-2.jpg
# Saved a0_TR005854-2.jpg
# Saved a0_TR005855-2.jpg
# Saved a0_TR005856-2.jpg
# Saved a0_TR005857-2.jpg
# Saved a0_TR005858-2.jpg
# Saved a0_TR005859-2.jpg
# Saved a0_TR005860-2.jpg
# Saved a0_TR005861-2.jpg
# Saved a0_TR005862-2.jpg
# Saved a0_TR005863-2.jpg
# Saved a0_TR005864-2.jpg
# Saved a0_TR005866-2.jpg
# Saved a0_TR005867-2.jpg
# Saved a0_TR005868-2.jpg
# Saved a0_TR005869-2.jpg
# Saved a0_TR006236-2.jpg
# Saved a0_TR006559-2.jpg
# Saved a0_TR006685-2.jpg
# Saved a0_TR006815-2.jpg
# Saved a0_TR006816-2.jpg
# Saved a0_TR006817-2.jpg
# Saved a0_TR006818-2.jpg
# Saved a0_TR007323-2.jpg
# Saved a0_TR007468-2.jpg
# Saved a0_TR008323-2.jpg
# Saved a0_TR008392-2.jpg
# Saved a0_TR008393-2.jpg
# Saved a0_TR008878-2.jpg
# Saved a0_TR008955-2.jpg
# Saved a0_TR009420-2.jpg
# Saved a0_TR010094-2.jpg
# Saved a0_TR010095-2.jpg
# Saved a0_TR010096-2.jpg
# Saved a0_TR010097-2.jpg
# Saved a0_TR010099-2.jpg
# Saved a0_TR010100-2.jpg
# Saved a0_TR010102-2.jpg
# Saved a0_TR010240-2.jpg
# Saved a0_TR011537-2.jpg
# Saved a0_TR013844-2.jpg
# Saved a0_TR013845-2.jpg
# Saved a0_TR013873-2.jpg
# Saved a0_TR013875-2.jpg
# Saved a0_TR013889-2.jpg
# Saved a0_TR013892-2-7-7.jpg
# Saved a0_TR013894-2-3.jpg
# Saved a0_TR013896-2.jpg
# Saved a0_TR014057-2.jpg
# Saved a0_TR014075-2.jpg
# Saved a0_TR014085-2.jpg
# Saved a0_TR014086-2.jpg
# Saved a0_TR014087-2.jpg
# Saved a0_TR014089-2.jpg
# Saved a0_TR014092-2.jpg
# Saved a0_TR014093-2.jpg
# Saved a0_TR014137-2-7.jpg
# Saved a0_TR014138-2.jpg
# Saved a0_TR014139-2.jpg
# Saved a0_TR014142-2.jpg
# Saved a0_TR014143-2-8.jpg
# Saved a0_TR014144-2.jpg
# Saved a0_TR014190-2.jpg
# Saved a0_TR014191-2.jpg
# Saved a0_TR014192-2.jpg
# Saved a0_TR014382-2.jpg
# Saved a0_TT000015-2.jpg
# Saved a0_TT000100-2.jpg
# Saved a0_TT000101-2.jpg
# Saved a0_TT000102-2.jpg
# Saved a0_TT000103-2.jpg
# Saved a0_TT000104-2.jpg
# Saved a0_TT000105-2.jpg
# Saved a0_TT000107-2.jpg
# Saved a0_TT000108-2.jpg
# Saved a0_TT000109-2.jpg
# Saved a0_TT000110-2.jpg
# Saved a0_TT000186-2.jpg
# Saved a0_TT000396-2.jpg
# Saved a0_TT000397-2.jpg
# Saved a0_TT000398-2.jpg
# Saved a0_TT000399-2-8-8.jpg
# Saved a0_TT000474-2.jpg
# Saved a0_TT000642-2-7-8.jpg
# Saved a0_TT001309-2.jpg
# Saved a0_TT001710-2.jpg
# Augmentation successfull
